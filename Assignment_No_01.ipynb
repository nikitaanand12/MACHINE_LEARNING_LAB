# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitaanand12/MACHINE_LEARNING_LAB/blob/main/Assignment_No_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("apple fruit",limit=40,output_dir='images')
# Out:
# [%] Downloading Images to /content/images/apple fruit
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 9 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.african-organic.com/wp-content/uploads/2015/08/Prod-Applebananas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.thestar.com/content/dam/thestar/life/homes/outdoor_living/2011/04/20/chopping_grafting_can_result_in_beautiful_fruit_trees/grafting.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://keyserver.lucidcentral.org/weeds/data/media/Images/ziziphus_mauritiana/ziziphusmauritiana2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://homesfeed.com/wp-content/uploads/2015/09/classic-scrolled-iron-tiered-fruit-stand-idea-with-two-storey-with-holder-and-three-legs.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://live.staticflickr.com/3659/3326837549_9d9e9db659_b.jpg
# [%] File Downloaded !
#
# ...

# %%
# !mkdir more_images

# %%
from bing_image_downloader import downloader
downloader.download("fruits",limit=20,output_dir='more_images')
# Out:
# [%] Downloading Images to /content/more_images/fruits
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 9 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.ecosnippets.com/wp-content/uploads/2013/10/shelves.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://wallpapershome.com/images/wallpapers/grapes-3840x2160-4k-15355.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://wallpapershome.com/images/wallpapers/grapes-7680x4320-8k-16059.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.healthyfoodhouse.com/wp-content/uploads/2017/02/columnar-fruit-trees-create-city-orchard-amazing-dwarf-fruit-trees1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://d2seqvvyy3b8p2.cloudfront.net/170ed6179032ed5578cd0285e284efa9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://img.thrfun.com/img/091/521/bittersweet_x.jpg
# [%] File Downloaded !
#
# ...

# %%
# !mkdir apples

# %%
from bing_image_downloader import downloader
downloader.download("apple fruit images only",limit=10,output_dir='apples')
# Out:
# [%] Downloading Images to /content/apples/apple fruit images only
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.shopify.com/s/files/1/0434/5793/7576/products/image_ab2e343d-848c-4c8f-a83e-574904d849d2_1075x1077.png?v=1617731021
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://betweennapsontheporch.net/wp-content/uploads/blogger/_x908CSKJhI4/TRe0IkMKFSI/AAAAAAAAV8o/6i1Ky8eZFUk/s800/33.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://d.ibtimes.co.uk/en/full/1398577/apple-watch-iphone-6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.magforwomen.com/wp-content/uploads/2013/02/rare-fruits.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://wallsdesk.com/wp-content/uploads/2018/04/Fig-High-Definition-Wallpapers.jpg
# [%] File Downloaded !
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
